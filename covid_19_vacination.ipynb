# %%
pwd
# Out:
# 'C:\\Users\\eniola\\Documents\\coven works'

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('Covid 19 vaccination Data.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4241 entries, 0 to 4240
# Data columns (total 15 columns):
# country                                4241 non-null object
# iso_code                               3945 non-null object
# date                                   4241 non-null object
# total_vaccinations                     2786 non-null float64
# people_vaccinated                      2366 non-null float64
# people_fully_vaccinated                1576 non-null float64
# daily_vaccinations_raw                 2357 non-null float64
# daily_vaccinations                     4092 non-null float64
# total_vaccinations_per_hundred         2786 non-null float64
# people_vaccinated_per_hundred          2366 non-null float64
# people_fully_vaccinated_per_hundred    1576 non-null float64
# daily_vaccinations_per_million         4092 non-null float64
# vaccines                               4241 non-null object
# source_name                            4241 non-null object
# ...

# %%
dataset.tail()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 4236  Zimbabwe      ZWE  2/21/2021                 NaN                NaN
# 4237  Zimbabwe      ZWE  2/22/2021              1314.0             1314.0
# 4238  Zimbabwe      ZWE  2/23/2021              4041.0             4041.0
# 4239  Zimbabwe      ZWE  2/24/2021              7872.0             7872.0
# 4240  Zimbabwe      ZWE  2/25/2021             11007.0            11007.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 4236                      NaN                     NaN               328.0
# 4237                      NaN                     NaN               328.0
# 4238                      NaN                  2727.0               808.0
# 4239                      NaN                  3831.0              1312.0
# 4240                      NaN                  3135.0              1572.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
dataset.isnull().sum()
# Out:
# country                                   0
# iso_code                                296
# date                                      0
# total_vaccinations                     1455
# people_vaccinated                      1875
# people_fully_vaccinated                2665
# daily_vaccinations_raw                 1884
# daily_vaccinations                      149
# total_vaccinations_per_hundred         1455
# people_vaccinated_per_hundred          1875
# people_fully_vaccinated_per_hundred    2665
# daily_vaccinations_per_million          149
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
dataset.describe(include='all')
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# count     4241     3945       4241        2.786000e+03       2.366000e+03
# unique     107      103         75                 NaN                NaN
# top      Wales      GBR  2/17/2021                 NaN                NaN
# freq        74       74         89                 NaN                NaN
# mean       NaN      NaN        NaN        1.645370e+06       1.430550e+06
# std        NaN      NaN        NaN        5.537536e+06       4.490582e+06
# min        NaN      NaN        NaN        0.000000e+00       0.000000e+00
# 25%        NaN      NaN        NaN        3.123275e+04       2.797800e+04
# 50%        NaN      NaN        NaN        1.991035e+05       1.792185e+05
# 75%        NaN      NaN        NaN        8.268740e+05       7.010685e+05
# max        NaN      NaN        NaN        6.827412e+07       4.607439e+07
#
#         people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, iso_code, date, total_vaccinations, people_vaccinated, people_fully_vaccinated, daily_vaccinations_raw, daily_vaccinations, total_vaccinations_per_hundred, people_vaccinated_per_hundred, people_fully_vaccinated_per_hundred, daily_vaccinations_per_million, vaccines, source_name, source_website]
# Index: []

# %%
dataset.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
dataset.head(10)
# Out:
#    country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  1/10/2021                 0.0                0.0
# 1  Albania      ALB  1/11/2021                 NaN                NaN
# 2  Albania      ALB  1/12/2021               128.0              128.0
# 3  Albania      ALB  1/13/2021               188.0              188.0
# 4  Albania      ALB  1/14/2021               266.0              266.0
# 5  Albania      ALB  1/15/2021               308.0              308.0
# 6  Albania      ALB  1/16/2021               369.0              369.0
# 7  Albania      ALB  1/17/2021               405.0              405.0
# 8  Albania      ALB  1/18/2021               447.0              447.0
# 9  Albania      ALB  1/19/2021               483.0              483.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
dataset.shape
# Out:
# (4241, 15)

# %%
dataset.drop(['source_name','source_website'],axis=1, inplace=True)

# %%
dataset.head(10)
# Out:
#    country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  1/10/2021                 0.0                0.0
# 1  Albania      ALB  1/11/2021                 NaN                NaN
# 2  Albania      ALB  1/12/2021               128.0              128.0
# 3  Albania      ALB  1/13/2021               188.0              188.0
# 4  Albania      ALB  1/14/2021               266.0              266.0
# 5  Albania      ALB  1/15/2021               308.0              308.0
# 6  Albania      ALB  1/16/2021               369.0              369.0
# 7  Albania      ALB  1/17/2021               405.0              405.0
# 8  Albania      ALB  1/18/2021               447.0              447.0
# 9  Albania      ALB  1/19/2021               483.0              483.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
dataset['country'].unique()
# Out:
# array(['Albania', 'Algeria', 'Andorra', 'Anguilla', 'Argentina',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Bermuda', 'Bolivia', 'Brazil',
#        'Bulgaria', 'Cambodia', 'Canada', 'Cayman Islands', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'England', 'Estonia', 'Faeroe Islands', 'Falkland Islands',
#        'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Greenland',
#        'Guernsey', 'Guyana', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Japan',
#        'Jersey', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Macao', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Monaco', 'Morocco', 'Myanmar', 'Nepal',
# ...

# %%
dataset=dataset[dataset['country'].apply(lambda x: x not in ['England','Wales','Northern Ireland','Scotland'])]

# %%
#Making a list to store the total occurence of each country in our dataset.
lists=[]
for i in range(94):
    lists.append(dataset['country'].value_counts()[i])

# %%
#lists

# %%
dataset['vaccines'].value_counts().unique
# Out:
# <bound method Series.unique of Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1151
# Pfizer/BioNTech                                                                        913
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    382
# Moderna, Pfizer/BioNTech                                                               356
# Sputnik V                                                                              217
# Oxford/AstraZeneca                                                                     210
# Sinovac                                                                                 89
# Oxford/AstraZeneca, Sinopharm/Beijing                                                   75
# Pfizer/BioNTech, Sinovac                                                                73
# Pfizer/BioNTech, Sinopharm/Beijing                                                      65
# ...

# %%
dataset['vaccines'].isnull().sum()
# Out:
# 0

# %%
#dataset['vaccines'].unique()

# %%
#dataset.plot['vaccines'].value_counts() 
dataset['vaccines'].value_counts().plot.bar(x=dataset['vaccines'], y=dataset['vaccines'].value_counts())

# %%
#which country is using which vaccines
dataset['country'].value_counts().plot.line()
